# %%
column_names = [f'Column {i+1}'for i in range(10)]
column_names
# Out:
# ['Column 1',
#  'Column 2',
#  'Column 3',
#  'Column 4',
#  'Column 5',
#  'Column 6',
#  'Column 7',
#  'Column 8',
#  'Column 9',
#  'Column 10']
